# %%
# !pip install pandas
# !pip install numpy
# !pip install plotly-express
# !pip install ipywidgets
# Out:
# Requirement already satisfied: pandas in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: plotly-express in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly-express) (2.2.1)
# Requirement already satisfied: plotly>=4.1.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly-express) (5.22.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly-express) (0.14.2)
# Requirement already satisfied: scipy>=0.18 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly-express) (1.13.0)
# Requirement already satisfied: patsy>=0.5 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly-express) (0.5.6)
# Requirement already satisfied: numpy>=1.11 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly-express) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pandas>=0.20.0->plotly-express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pandas>=0.20.0->plotly-express) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pandas>=0.20.0->plotly-express) (2023.3)
# Requirement already satisfied: six in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from patsy>=0.5->plotly-express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly>=4.1.0->plotly-express) (8.3.0)
# Requirement already satisfied: packaging in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from plotly>=4.1.0->plotly-express) (23.2)
# Requirement already satisfied: ipywidgets in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (8.1.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipywidgets) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: decorator in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /Users/hoangleduc/ironhack/ih-labs/env/lib/python3.12/site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
import pandas as pd
import numpy as np
import plotly_express as px
import ipywidgets as widgets
import ast
from math import nan
import warnings
warnings.filterwarnings('ignore')

# %%
playset = pd.read_csv('blackjack_simulator.csv', sep = ',' , nrows = 250000)  # Because 5M lines total 
playset.head(10)
# Out:
#    shoe_id  cards_remaining  dealer_up initial_hand   dealer_final  \
# 0        0              416         10     [10, 11]    [10, 4, 10]
# 1        0              411         10       [5, 5]        [10, 8]
# 2        0              406          6      [3, 10]     [6, 6, 10]
# 3        0              401         10       [5, 9]        [10, 8]
# 4        0              395          8      [6, 10]     [8, 2, 10]
# 5        0              389          7       [3, 4]     [7, 2, 10]
# 6        0              383          6       [3, 3]    [6, 10, 10]
# 7        0              374          3      [10, 8]     [3, 10, 7]
# 8        0              369          5      [8, 10]     [5, 10, 9]
# 9        0              364          9       [6, 8]  [9, 2, 5, 11]
#
#   dealer_final_value             player_final player_final_value  \
# 0                 24               [[10, 11]]             ['BJ']
# 1                 18             [[5, 5, 11]]               [21]
# 2                 22                [[3, 10]]               [13]
# 3                 18          [[5, 9, 11, 3]]               [18]
# 4                 20            [[6, 10, 10]]               [26]
# 5                 19             [[3, 4, 11]]               [18]
# 6                 26  [[3, 2, 10], [3, 4, 5]]           [15, 12]
# 7                 20                [[10, 8]]               [18]
# 8                 24                [[8, 10]]               [18]
# 9                 17              [[6, 8, 6]]               [20]
#
#                    actions_taken  run_count  true_count  win
# 0                        [['S']]          1           0  1.5
# 1                   [['H', 'S']]         -2           0  1.0
# 2                        [['S']]         -2           0  1.0
# 3              [['H', 'H', 'S']]         -1           0  0.0
# 4                        [['H']]         -1           0 -1.0
# 5                   [['H', 'S']]         -2           0 -1.0
# 6  [['P', 'H', 'S'], ['H', 'S']]         -1           0  2.0
# 7                        [['S']]          2           0 -1.0
# 8                        [['S']]          1           0  1.0
# 9                   [['H', 'S']]          0           0  1.0

# %% [markdown]
# Action	Description
# H	Hit
# S	Stand
# D	Double Down
# P	Split
# R	Surrender
# I	Buy Insurance (Never used since player is following Basic Strategy)
# N	No Insurance (Dont care?)
# Re-splitting Aces is not allowed
# Splitting Aces receives 1 extra card only, no Blackjack
# Late surrender allowed
# No surrender after split
# Dealer hits soft 17 - A(11) + wutever - Treat it like 1 and keep hiting
# Stay on hard 17

# %%
playset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   shoe_id             250000 non-null  int64
#  1   cards_remaining     250000 non-null  int64
#  2   dealer_up           250000 non-null  int64
#  3   initial_hand        250000 non-null  object
#  4   dealer_final        250000 non-null  object
#  5   dealer_final_value  250000 non-null  object
#  6   player_final        250000 non-null  object
#  7   player_final_value  250000 non-null  object
#  8   actions_taken       250000 non-null  object
#  9   run_count           250000 non-null  int64
#  10  true_count          250000 non-null  int64
#  11  win                 250000 non-null  float64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 22.9+ MB

# %%
# playset.describe()

# %%
type(playset['initial_hand'][1]) , type(playset['dealer_final'][1])
# Out:
# (str, str)

# %% [markdown]
#  3   initial_hand        250000 non-null  object
#  4   dealer_final        250000 non-null  object
#  5   dealer_final_value  250000 non-null  object
#  6   player_final        250000 non-null  object
#  7   player_final_value  250000 non-null  object
#  This is all string represent of list ? convert them into List

# %%
playset['initial_hand'] = playset['initial_hand'].apply(lambda x: ast.literal_eval(x))
playset['dealer_final'] = playset['dealer_final'].apply(lambda x: ast.literal_eval(x))
playset['player_final'] = playset['player_final'].apply(lambda x: ast.literal_eval(x))
playset['player_final_value'] = playset['player_final_value'].apply(lambda x: ast.literal_eval(x))	
playset['actions_taken'] = playset['actions_taken'].apply(lambda x: ast.literal_eval(x))

# %%
playset.info()
playset.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   shoe_id             250000 non-null  int64
#  1   cards_remaining     250000 non-null  int64
#  2   dealer_up           250000 non-null  int64
#  3   initial_hand        250000 non-null  object
#  4   dealer_final        250000 non-null  object
#  5   dealer_final_value  250000 non-null  object
#  6   player_final        250000 non-null  object
#  7   player_final_value  250000 non-null  object
#  8   actions_taken       250000 non-null  object
#  9   run_count           250000 non-null  int64
#  10  true_count          250000 non-null  int64
#  11  win                 250000 non-null  float64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 22.9+ MB
#    shoe_id  cards_remaining  dealer_up initial_hand   dealer_final  \
# 0        0              416         10     [10, 11]    [10, 4, 10]
# 1        0              411         10       [5, 5]        [10, 8]
# 2        0              406          6      [3, 10]     [6, 6, 10]
# 3        0              401         10       [5, 9]        [10, 8]
# 4        0              395          8      [6, 10]     [8, 2, 10]
# 5        0              389          7       [3, 4]     [7, 2, 10]
# 6        0              383          6       [3, 3]    [6, 10, 10]
# 7        0              374          3      [10, 8]     [3, 10, 7]
# 8        0              369          5      [8, 10]     [5, 10, 9]
# 9        0              364          9       [6, 8]  [9, 2, 5, 11]
#
#   dealer_final_value             player_final player_final_value  \
# 0                 24               [[10, 11]]               [BJ]
# 1                 18             [[5, 5, 11]]               [21]
# 2                 22                [[3, 10]]               [13]
# 3                 18          [[5, 9, 11, 3]]               [18]
# 4                 20            [[6, 10, 10]]               [26]
# 5                 19             [[3, 4, 11]]               [18]
# 6                 26  [[3, 2, 10], [3, 4, 5]]           [15, 12]
# 7                 20                [[10, 8]]               [18]
# 8                 24                [[8, 10]]               [18]
# 9                 17              [[6, 8, 6]]               [20]
#
#          actions_taken  run_count  true_count  win
# 0                [[S]]          1           0  1.5
# 1             [[H, S]]         -2           0  1.0
# 2                [[S]]         -2           0  1.0
# 3          [[H, H, S]]         -1           0  0.0
# 4                [[H]]         -1           0 -1.0
# 5             [[H, S]]         -2           0 -1.0
# 6  [[P, H, S], [H, S]]         -1           0  2.0
# 7                [[S]]          2           0 -1.0
# 8                [[S]]          1           0  1.0
# 9             [[H, S]]          0           0  1.0

# %% [markdown]
# 6	0	383	6	[3, 3]	[6, 10, 10]	26	[[3, 2, 10], [3, 4, 5]]	[15, 12]	[[P, H, S], [H, S]]	-1	0	2.
